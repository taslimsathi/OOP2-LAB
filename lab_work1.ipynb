# %% [markdown]
# <a href="https://colab.research.google.com/github/taslimsathi/OOP2-LAB/blob/master/lab_work1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#built-in functions

print("Hi, I am sathi. Do you miss me?")
print("Let me know if you miss me or not. ")
s=input()

a=10
b=21
print(max(a,b))
print(min(a,b))

c=10.4
d=int(c)
print(d)

e="python"
print(type(e))
# Out:
# Hi, I am sathi. Do you miss me?
# Let me know if you miss me or not.
# yes
# 21
# 10
# 10
# <class 'str'>

# %%
#user defined function

def add(a, b):
    c=a+b
    return c

a=int(input("Enter a number: "))
b=int(input("Enter a number: "))
d=add(a,b)
print("The sum is", d)

# %%
#function with multiple parameters

def divisor(x,y,m):
    if x%m==0 and y%m==0:
        print("%d & %d are divisible by %d"%(x,y,m))
    elif x%m==0:
        print("only %d is divisible by %d"%(x,m))
    elif y%m==0:
        print("only %d is divisible by %d"%(y,m))
    else:
        print("none of %d & %d is divisible by %d"%(x,y,d))

divisor(10,20,5)
divisor(12,20,5)
divisor(10,22,5)
divisor(2,5,3)
# Out:
# 10 & 20 are divisible by 5
# only 20 is divisible by 5
# only 10 is divisible by 5
# none of 2 & 5 is divisible by 30

# %%
#function without parameter

def summation():
    a=3+8
    return a

b=summation()
print(b)
# Out:
# 11

# %%
#function with default parameter value

def check(a=0):
    if a==0:
        print("Zero")
    elif a>0:
        print("Positive")
    else:
        print("Negative")

check()     #without parameter
check(-4)   #with parameter
# Out:
# Zero
# Negative

# %%
#global scope

x=10

def global_scope():
    print(x)

print(x)
global_scope()
# Out:
# 10
# 10

# %%
#global scope

def global_scope():
    global x
    x=10

global_scope()
print(x)
# Out:
# 10

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#python standard library
#csv module

import csv

with open('gdrive/My Drive/Colab Notebooks/first.csv', newline='') as csvfile:
    tmp = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in tmp:
        print(', '.join(row))
# Out:
# Overall, rank,Country, or, region,Score,GDP, per, capita,Social, support,Healthy, life, expectancy,Freedom, to, make, life, choices,Generosity,Perceptions, of, corruption
# 1,Finland,7.769,1.340,1.587,0.986,0.596,0.153,0.393
# 2,Denmark,7.600,1.383,1.573,0.996,0.592,0.252,0.410
# 3,Norway,7.554,1.488,1.582,1.028,0.603,0.271,0.341
# 4,Iceland,7.494,1.380,1.624,1.026,0.591,0.354,0.118
# 5,Netherlands,7.488,1.396,1.522,0.999,0.557,0.322,0.298
# 6,Switzerland,7.480,1.452,1.526,1.052,0.572,0.263,0.343
# 7,Sweden,7.343,1.387,1.487,1.009,0.574,0.267,0.373
# 8,New, Zealand,7.307,1.303,1.557,1.026,0.585,0.330,0.380
# 9,Canada,7.278,1.365,1.505,1.039,0.584,0.285,0.308
# 10,Austria,7.246,1.376,1.475,1.016,0.532,0.244,0.226
# 11,Australia,7.228,1.372,1.548,1.036,0.557,0.332,0.290
# 12,Costa, Rica,7.167,1.034,1.441,0.963,0.558,0.144,0.093
# 13,Israel,7.139,1.276,1.455,1.029,0.371,0.261,0.082
# 14,Luxembourg,7.090,1.609,1.479,1.012,0.526,0.194,0.316
# ...

# %%
import pandas as sathi

# %%
data=sathi.read_csv('gdrive/My Drive/Colab Notebooks/first.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
data.head(50)
# Out:
#     Overall rank     Country or region  ...  Generosity  Perceptions of corruption
# 0              1               Finland  ...       0.153                      0.393
# 1              2               Denmark  ...       0.252                      0.410
# 2              3                Norway  ...       0.271                      0.341
# 3              4               Iceland  ...       0.354                      0.118
# 4              5           Netherlands  ...       0.322                      0.298
# 5              6           Switzerland  ...       0.263                      0.343
# 6              7                Sweden  ...       0.267                      0.373
# 7              8           New Zealand  ...       0.330                      0.380
# 8              9                Canada  ...       0.285                      0.308
# 9             10               Austria  ...       0.244                      0.226
# ...

# %%
data.tail(2)
# Out:
#      Overall rank  ... Perceptions of corruption
# 154           155  ...                     0.035
# 155           156  ...                     0.091
#
# [2 rows x 9 columns]

# %%
data.shape
# Out:
# (156, 9)

# %%
#python standard library
#math module

import math

print(math.pi)          #value of pi

x=9.2
print(math.ceil(x))     #round to the smallest integer not less than x
print(math.floor(x))    #rount to the largest integer not greater than x

print(math.sin(78))     #trigonometric sine of x (x in radians)

print(math.pow(2,3))    #2 to the power 3

print(math.sqrt(16))    #square root of 16
# Out:
# 3.141592653589793
# 10
# 9
# 0.5139784559875352
# 8.0
# 4.0
